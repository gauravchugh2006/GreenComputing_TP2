# %% [markdown]
# # =========================
# # TP2 — Pandas Baseline
# # =========================

# %%
# !curl -L -o /content/sample.zip https://www.kaggle.com/api/v1/datasets/download/mohamedbakhet/amazon-books-reviews

# %%
import pandas as pd
import numpy as np
import re
import psutil
import time
from codecarbon import EmissionsTracker
from collections import Counter


# ---------------------------------------------
# Helper function to measure each pipeline step
# ---------------------------------------------
def measure_step(step_name, framework, func, log):
    co2_kg = 0.0
    start = 0.0
    try:
        tracker = EmissionsTracker(measure_power_secs=1, save_to_file=False)
        tracker.start()
        start = time.time()
        func()
        co2_kg = tracker.stop()  # may be None or float
    except Exception as e:
        print(f"⚠️ CodeCarbon failed for {step_name}: {e}")
        co2_kg = 0.0
    finally:
        duration = time.time() - start
        memory_mb = psutil.virtual_memory().used / (1024 * 1024)

        # Handle None safely
        if co2_kg is None:
            co2_kg = 0.0

        # Estimate energy from CO₂ (1 kWh ≈ 0.233 kg CO₂)
        energy_kwh = co2_kg / 0.233 if co2_kg and co2_kg > 0 else 0.0

        log.append({
            "Step": step_name,
            "Framework": framework,
            "Duration (s)": round(duration, 3),
            "Energy (kWh)": round(energy_kwh, 6),
            "CO2 (kg)": round(co2_kg, 6),
            "Memory (MB)": round(memory_mb, 2)
        })

# %% [markdown]
# # =========================================================
# # ----------- TASK 1 : PANDAS PIPELINE ---------------------
# # =========================================================

# %%
log_pandas = []

def pandas_pipeline():
    print("Running Pandas pipeline...")
    global books, reviews, merged, author_ratings, reviews_per_publisher, category_reviews, most_common_words

    # ---- Load ----
    def step_load_data():
        global books, reviews
        books = pd.read_csv("books_data.csv")
        reviews = pd.read_csv("Books_rating.csv")
    # measure_step("Load data", "Pandas", step_load_data, log_pandas)

    # ---- Clean ----
    def step_clean_data():
        books.fillna({"description": "", "publisher": "Unknown", "categories": "[]", "authors": "[]"}, inplace=True)
        reviews.fillna({"Price": 0, "review/text": "", "review/summary": ""}, inplace=True)

        def clean_list_column(x):
            if pd.isna(x): return []
            x = re.sub(r"[\[\]']", "", str(x))
            return [i.strip() for i in x.split(",") if i.strip()]

        books["authors"] = books["authors"].apply(clean_list_column)
        books["categories"] = books["categories"].apply(clean_list_column)
    # measure_step("Data cleaning", "Pandas", step_clean_data, log_pandas)

    # ---- Join ----
    def step_join_data():
        global merged
        merged = pd.merge(reviews, books, on="Title", how="inner")
    # measure_step("Join datasets", "Pandas", step_join_data, log_pandas)

    # ---- Compute metrics ----
    def step_avg_rating_per_author():
        global author_ratings
        author_ratings = (
            merged.explode("authors")
            .groupby("authors")["review/score"]
            .mean()
            .reset_index()
            .rename(columns={"review/score": "avg_rating"})
        )
    measure_step("Average rating per author", "Pandas", step_avg_rating_per_author, log_pandas)

    def step_reviews_per_publisher():
        global reviews_per_publisher
        reviews_per_publisher = (
            merged.groupby("publisher")["Id"]
            .count()
            .reset_index()
            .rename(columns={"Id": "num_reviews"})
        )
    measure_step("Number of reviews per publisher", "Pandas", step_reviews_per_publisher, log_pandas)

    def step_top10_categories():
        global category_reviews
        category_reviews = (
            merged.explode("categories")
            .groupby("categories")["Id"]
            .count()
            .reset_index()
            .rename(columns={"Id": "num_reviews"})
            .sort_values(by="num_reviews", ascending=False)
            .head(10)
        )
    measure_step("Top 10 most-reviewed categories", "Pandas", step_top10_categories, log_pandas)

    # ---- Text processing ----
    def step_avg_review_length():
        merged["review_length"] = merged["review/text"].apply(lambda x: len(str(x).split()))
        merged["review_length"].mean()
    measure_step("Average review length", "Pandas", step_avg_review_length, log_pandas)

    def step_most_common_words():
        global most_common_words
        all_words = " ".join(merged["review/text"]).lower().split()
        word_counts = Counter(all_words)
        most_common_words = pd.DataFrame(word_counts.most_common(10), columns=["word", "count"])
    measure_step("Most frequent keywords", "Pandas", step_most_common_words, log_pandas)

    # ---- Save ----
    def step_save_results():
        author_ratings.to_csv("avg_rating_per_author.csv", index=False)
        reviews_per_publisher.to_csv("reviews_per_publisher.csv", index=False)
        category_reviews.to_csv("top10_categories.csv", index=False)
        most_common_words.to_csv("top10_keywords.csv", index=False)
    # measure_step("Save results", "Pandas", step_save_results, log_pandas)

    pd.DataFrame(log_pandas).to_csv("emissions_pandas.csv", index=False)
    print("✅ Pandas pipeline done → emissions_pandas.csv")

# Run Task 1
pandas_pipeline()
# Out:
# [codecarbon WARNING @ 10:45:54] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 10:45:54] [setup] RAM Tracking...
# [codecarbon INFO @ 10:45:54] [setup] CPU Tracking...
# Running Pandas pipeline...
# [codecarbon WARNING @ 10:45:56] We saw that you have a Intel(R) Core(TM) Ultra 9 185H but we don't know it. Please contact us.
# [codecarbon WARNING @ 10:45:56] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Windows OS detected: Please install Intel Power Gadget to measure CPU
#
# [codecarbon INFO @ 10:45:56] CPU Model on constant consumption mode: Intel(R) Core(TM) Ultra 9 185H
# [codecarbon WARNING @ 10:45:56] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 10:45:56] [setup] GPU Tracking...
# [codecarbon INFO @ 10:45:56] No GPU found.
# [codecarbon INFO @ 10:45:56] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: global constant
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 10:45:56] >>> Tracker's metadata:
# [codecarbon INFO @ 10:45:56]   Platform system: Windows-11-10.0.26200-SP0
# [codecarbon INFO @ 10:45:56]   Python version: 3.12.6
# [codecarbon INFO @ 10:45:56]   CodeCarbon version: 3.0.8
# [codecarbon INFO @ 10:45:56]   Available RAM : 31.435 GB
# [codecarbon INFO @ 10:45:56]   CPU count: 22 thread(s) in 22 physical CPU(s)
# [codecarbon INFO @ 10:45:56]   CPU model: Intel(R) Core(TM) Ultra 9 185H
# [codecarbon INFO @ 10:45:56]   GPU count: None
# [codecarbon INFO @ 10:45:56]   GPU model: None
# [codecarbon WARNING @ 10:45:57] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 10:45:57] [setup] RAM Tracking...
# [codecarbon INFO @ 10:45:57] [setup] CPU Tracking...
# ⚠️ CodeCarbon failed for Average rating per author: name 'merged' is not defined
# [codecarbon INFO @ 10:45:58] Energy consumed for RAM : 0.000006 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:45:58] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:45:58] Energy consumed for All CPU : 0.000012 kWh
# [codecarbon INFO @ 10:45:58] 0.000018 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon WARNING @ 10:45:59] We saw that you have a Intel(R) Core(TM) Ultra 9 185H but we don't know it. Please contact us.
# [codecarbon WARNING @ 10:45:59] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Windows OS detected: Please install Intel Power Gadget to measure CPU
#
# [codecarbon INFO @ 10:45:59] CPU Model on constant consumption mode: Intel(R) Core(TM) Ultra 9 185H
# [codecarbon WARNING @ 10:45:59] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 10:45:59] [setup] GPU Tracking...
# [codecarbon INFO @ 10:45:59] No GPU found.
# [codecarbon INFO @ 10:45:59] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: global constant
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 10:45:59] >>> Tracker's metadata:
# [codecarbon INFO @ 10:45:59]   Platform system: Windows-11-10.0.26200-SP0
# [codecarbon INFO @ 10:45:59]   Python version: 3.12.6
# [codecarbon INFO @ 10:45:59]   CodeCarbon version: 3.0.8
# [codecarbon INFO @ 10:45:59]   Available RAM : 31.435 GB
# [codecarbon INFO @ 10:45:59]   CPU count: 22 thread(s) in 22 physical CPU(s)
# [codecarbon INFO @ 10:45:59]   CPU model: Intel(R) Core(TM) Ultra 9 185H
# [codecarbon INFO @ 10:45:59]   GPU count: None
# [codecarbon INFO @ 10:45:59]   GPU model: None
# [codecarbon INFO @ 10:45:59] Energy consumed for RAM : 0.000011 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:45:59] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:45:59] Energy consumed for All CPU : 0.000024 kWh
# [codecarbon INFO @ 10:45:59] 0.000035 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon WARNING @ 10:45:59] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 10:45:59] [setup] RAM Tracking...
# [codecarbon INFO @ 10:45:59] [setup] CPU Tracking...
# ⚠️ CodeCarbon failed for Number of reviews per publisher: name 'merged' is not defined
# [codecarbon INFO @ 10:46:00] Energy consumed for RAM : 0.000017 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:00] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:00] Energy consumed for All CPU : 0.000036 kWh
# [codecarbon INFO @ 10:46:00] 0.000053 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:00] Energy consumed for RAM : 0.000006 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:00] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:00] Energy consumed for All CPU : 0.000012 kWh
# [codecarbon INFO @ 10:46:00] 0.000018 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:01] Energy consumed for RAM : 0.000022 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:01] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:01] Energy consumed for All CPU : 0.000048 kWh
# [codecarbon INFO @ 10:46:01] 0.000070 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon WARNING @ 10:46:01] We saw that you have a Intel(R) Core(TM) Ultra 9 185H but we don't know it. Please contact us.
# [codecarbon WARNING @ 10:46:01] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Windows OS detected: Please install Intel Power Gadget to measure CPU
#
# [codecarbon INFO @ 10:46:01] CPU Model on constant consumption mode: Intel(R) Core(TM) Ultra 9 185H
# [codecarbon WARNING @ 10:46:01] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 10:46:01] [setup] GPU Tracking...
# [codecarbon INFO @ 10:46:01] No GPU found.
# [codecarbon INFO @ 10:46:01] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: global constant
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 10:46:01] >>> Tracker's metadata:
# [codecarbon INFO @ 10:46:01]   Platform system: Windows-11-10.0.26200-SP0
# [codecarbon INFO @ 10:46:01]   Python version: 3.12.6
# [codecarbon INFO @ 10:46:01]   CodeCarbon version: 3.0.8
# [codecarbon INFO @ 10:46:01]   Available RAM : 31.435 GB
# [codecarbon INFO @ 10:46:01]   CPU count: 22 thread(s) in 22 physical CPU(s)
# [codecarbon INFO @ 10:46:01]   CPU model: Intel(R) Core(TM) Ultra 9 185H
# [codecarbon INFO @ 10:46:01]   GPU count: None
# [codecarbon INFO @ 10:46:01]   GPU model: None
# [codecarbon INFO @ 10:46:01] Energy consumed for RAM : 0.000011 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:01] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:01] Energy consumed for All CPU : 0.000024 kWh
# [codecarbon INFO @ 10:46:01] 0.000035 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon WARNING @ 10:46:02] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 10:46:02] [setup] RAM Tracking...
# [codecarbon INFO @ 10:46:02] [setup] CPU Tracking...
# [codecarbon INFO @ 10:46:02] Energy consumed for RAM : 0.000028 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:02] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:02] Energy consumed for All CPU : 0.000059 kWh
# [codecarbon INFO @ 10:46:02] 0.000087 kWh of electricity and 0.000000 L of water were used since the beginning.
# ⚠️ CodeCarbon failed for Top 10 most-reviewed categories: name 'merged' is not defined
# [codecarbon INFO @ 10:46:02] Energy consumed for RAM : 0.000017 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:02] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:02] Energy consumed for All CPU : 0.000036 kWh
# [codecarbon INFO @ 10:46:02] 0.000052 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:03] Energy consumed for RAM : 0.000006 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:03] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:03] Energy consumed for All CPU : 0.000012 kWh
# [codecarbon INFO @ 10:46:03] 0.000018 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:03] Energy consumed for RAM : 0.000033 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:03] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:03] Energy consumed for All CPU : 0.000071 kWh
# [codecarbon INFO @ 10:46:03] 0.000105 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:03] Energy consumed for RAM : 0.000022 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:03] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:03] Energy consumed for All CPU : 0.000047 kWh
# [codecarbon INFO @ 10:46:03] 0.000069 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon WARNING @ 10:46:03] We saw that you have a Intel(R) Core(TM) Ultra 9 185H but we don't know it. Please contact us.
# [codecarbon WARNING @ 10:46:03] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Windows OS detected: Please install Intel Power Gadget to measure CPU
#
# [codecarbon INFO @ 10:46:03] CPU Model on constant consumption mode: Intel(R) Core(TM) Ultra 9 185H
# [codecarbon WARNING @ 10:46:03] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 10:46:03] [setup] GPU Tracking...
# [codecarbon INFO @ 10:46:03] No GPU found.
# [codecarbon INFO @ 10:46:03] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: global constant
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 10:46:03] >>> Tracker's metadata:
# [codecarbon INFO @ 10:46:03]   Platform system: Windows-11-10.0.26200-SP0
# [codecarbon INFO @ 10:46:03]   Python version: 3.12.6
# [codecarbon INFO @ 10:46:03]   CodeCarbon version: 3.0.8
# [codecarbon INFO @ 10:46:03]   Available RAM : 31.435 GB
# [codecarbon INFO @ 10:46:03]   CPU count: 22 thread(s) in 22 physical CPU(s)
# [codecarbon INFO @ 10:46:03]   CPU model: Intel(R) Core(TM) Ultra 9 185H
# [codecarbon INFO @ 10:46:03]   GPU count: None
# [codecarbon INFO @ 10:46:03]   GPU model: None
# [codecarbon INFO @ 10:46:04] Energy consumed for RAM : 0.000011 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:04] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:04] Energy consumed for All CPU : 0.000024 kWh
# [codecarbon INFO @ 10:46:04] 0.000035 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:04] Energy consumed for RAM : 0.000039 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:04] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:04] Energy consumed for All CPU : 0.000083 kWh
# [codecarbon INFO @ 10:46:04] 0.000122 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon WARNING @ 10:46:04] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 10:46:04] [setup] RAM Tracking...
# [codecarbon INFO @ 10:46:04] [setup] CPU Tracking...
# [codecarbon INFO @ 10:46:04] Energy consumed for RAM : 0.000028 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:04] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:04] Energy consumed for All CPU : 0.000059 kWh
# [codecarbon INFO @ 10:46:04] 0.000087 kWh of electricity and 0.000000 L of water were used since the beginning.
# ⚠️ CodeCarbon failed for Average review length: name 'merged' is not defined
# [codecarbon INFO @ 10:46:05] Energy consumed for RAM : 0.000017 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:05] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:05] Energy consumed for All CPU : 0.000036 kWh
# [codecarbon INFO @ 10:46:05] 0.000052 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:05] Energy consumed for RAM : 0.000044 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:05] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:05] Energy consumed for All CPU : 0.000095 kWh
# [codecarbon INFO @ 10:46:05] 0.000139 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:05] Energy consumed for RAM : 0.000006 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:05] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:05] Energy consumed for All CPU : 0.000012 kWh
# [codecarbon INFO @ 10:46:05] 0.000018 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:05] Energy consumed for RAM : 0.000033 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:05] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:05] Energy consumed for All CPU : 0.000071 kWh
# [codecarbon INFO @ 10:46:05] 0.000104 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:06] Energy consumed for RAM : 0.000022 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:06] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:06] Energy consumed for All CPU : 0.000048 kWh
# [codecarbon INFO @ 10:46:06] 0.000070 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:06] Energy consumed for RAM : 0.000050 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:06] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:06] Energy consumed for All CPU : 0.000107 kWh
# [codecarbon INFO @ 10:46:06] 0.000157 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon WARNING @ 10:46:06] We saw that you have a Intel(R) Core(TM) Ultra 9 185H but we don't know it. Please contact us.
# [codecarbon WARNING @ 10:46:06] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Windows OS detected: Please install Intel Power Gadget to measure CPU
#
# [codecarbon INFO @ 10:46:06] CPU Model on constant consumption mode: Intel(R) Core(TM) Ultra 9 185H
# [codecarbon WARNING @ 10:46:06] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 10:46:06] [setup] GPU Tracking...
# [codecarbon INFO @ 10:46:06] No GPU found.
# [codecarbon INFO @ 10:46:06] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: global constant
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 10:46:06] >>> Tracker's metadata:
# [codecarbon INFO @ 10:46:06]   Platform system: Windows-11-10.0.26200-SP0
# [codecarbon INFO @ 10:46:06]   Python version: 3.12.6
# [codecarbon INFO @ 10:46:06]   CodeCarbon version: 3.0.8
# [codecarbon INFO @ 10:46:06]   Available RAM : 31.435 GB
# [codecarbon INFO @ 10:46:06]   CPU count: 22 thread(s) in 22 physical CPU(s)
# [codecarbon INFO @ 10:46:06]   CPU model: Intel(R) Core(TM) Ultra 9 185H
# [codecarbon INFO @ 10:46:06]   GPU count: None
# [codecarbon INFO @ 10:46:06]   GPU model: None
# [codecarbon INFO @ 10:46:06] Energy consumed for RAM : 0.000011 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:06] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:06] Energy consumed for All CPU : 0.000024 kWh
# [codecarbon INFO @ 10:46:06] 0.000035 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:06] Energy consumed for RAM : 0.000039 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:06] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:06] Energy consumed for All CPU : 0.000083 kWh
# [codecarbon INFO @ 10:46:06] 0.000122 kWh of electricity and 0.000000 L of water were used since the beginning.
# ⚠️ CodeCarbon failed for Most frequent keywords: name 'merged' is not defined
# ✅ Pandas pipeline done → emissions_pandas.csv

# %% [markdown]
# # =========================================================
# # ----------- TASK 2 : PYSPARK PIPELINE --------------------
# # =========================================================

# %%
pip install pyspark
# Out:
# [codecarbon INFO @ 10:46:07] Energy consumed for RAM : 0.000028 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:07] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:07] Energy consumed for All CPU : 0.000060 kWh
# [codecarbon INFO @ 10:46:07] 0.000087 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:07] Energy consumed for RAM : 0.000055 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:07] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:07] Energy consumed for All CPU : 0.000119 kWh
# [codecarbon INFO @ 10:46:07] 0.000174 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:07] Energy consumed for RAM : 0.000017 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:07] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:07] Energy consumed for All CPU : 0.000036 kWh
# [codecarbon INFO @ 10:46:07] 0.000052 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:07] Energy consumed for RAM : 0.000044 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:07] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:07] Energy consumed for All CPU : 0.000095 kWh
# [codecarbon INFO @ 10:46:07] 0.000139 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:07] Energy consumed for RAM : 0.000006 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:07] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:07] Energy consumed for All CPU : 0.000012 kWh
# [codecarbon INFO @ 10:46:07] 0.000018 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:08] Energy consumed for RAM : 0.000033 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:08] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:08] Energy consumed for All CPU : 0.000072 kWh
# [codecarbon INFO @ 10:46:08] 0.000105 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:08] Energy consumed for RAM : 0.000061 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:08] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:08] Energy consumed for All CPU : 0.000130 kWh
# [codecarbon INFO @ 10:46:08] 0.000191 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:08] Energy consumed for RAM : 0.000022 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:08] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:08] Energy consumed for All CPU : 0.000047 kWh
# [codecarbon INFO @ 10:46:08] 0.000069 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:08] Energy consumed for RAM : 0.000050 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:08] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:08] Energy consumed for All CPU : 0.000107 kWh
# [codecarbon INFO @ 10:46:08] 0.000156 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:08] Energy consumed for RAM : 0.000011 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:08] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:08] Energy consumed for All CPU : 0.000024 kWh
# [codecarbon INFO @ 10:46:08] 0.000035 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:09] Energy consumed for RAM : 0.000039 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:09] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:09] Energy consumed for All CPU : 0.000083 kWh
# [codecarbon INFO @ 10:46:09] 0.000122 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:09] Energy consumed for RAM : 0.000066 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:09] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:09] Energy consumed for All CPU : 0.000142 kWh
# [codecarbon INFO @ 10:46:09] 0.000209 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:09] Energy consumed for RAM : 0.000028 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:09] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:09] Energy consumed for All CPU : 0.000059 kWh
# [codecarbon INFO @ 10:46:09] 0.000087 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:09] Energy consumed for RAM : 0.000055 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:09] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:09] Energy consumed for All CPU : 0.000118 kWh
# [codecarbon INFO @ 10:46:09] 0.000173 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:09] Energy consumed for RAM : 0.000017 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:09] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:09] Energy consumed for All CPU : 0.000036 kWh
# [codecarbon INFO @ 10:46:09] 0.000052 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:10] Energy consumed for RAM : 0.000044 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:10] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:10] Energy consumed for All CPU : 0.000095 kWh
# [codecarbon INFO @ 10:46:10] 0.000140 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:10] Energy consumed for RAM : 0.000072 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:10] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:10] Energy consumed for All CPU : 0.000154 kWh
# [codecarbon INFO @ 10:46:10] 0.000226 kWh of electricity and 0.000000 L of water were used since the beginning.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyspark in c:\users\gaurav chugh\appdata\roaming\python\python312\site-packages (3.5.4)
# Requirement already satisfied: py4j==0.10.9.7 in c:\users\gaurav chugh\appdata\roaming\python\python312\site-packages (from pyspark) (0.10.9.7)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, explode, split, size, lower, regexp_replace, avg, count

log_spark = []

def spark_pipeline():
    print("\nRunning PySpark pipeline...")

    spark = SparkSession.builder \
        .appName("Books Reviews Spark CodeCarbon") \
        .master("local[*]") \
        .getOrCreate()

    # ---- Load ----
    def step_load_data():
        global books_df, reviews_df
        books_df = spark.read.option("header", True).csv("books.csv")
        reviews_df = spark.read.option("header", True).csv("reviews.csv")

    # ---- Clean ----
    def step_clean_data():
        global books_df_clean, reviews_df_clean
        books_df_clean = books_df.fillna({
            "description": "",
            "publisher": "Unknown",
            "categories": "[]",
            "authors": "[]"
        })
        reviews_df_clean = reviews_df.fillna({
            "Price": "0",
            "review/text": "",
            "review/summary": ""
        })
        books_df_clean = books_df_clean \
            .withColumn("authors", regexp_replace(col("authors"), r"[\[\]']", "")) \
            .withColumn("categories", regexp_replace(col("categories"), r"[\[\]']", "")) \
            .withColumn("authors", split(col("authors"), ",")) \
            .withColumn("categories", split(col("categories"), ","))

    # ---- Join ----
    def step_join_data():
        global merged_df
        merged_df = reviews_df_clean.join(books_df_clean, on="Title", how="inner")

    # Call the data loading and preparation steps first
    step_load_data()
    step_clean_data() 
    step_join_data()

    # Then proceed with the metrics computation
    def step_avg_rating_per_author():
        global author_ratings_df
        author_ratings_df = merged_df.withColumn("author", explode(col("authors"))) \
            .groupby("author").agg(avg(col("review/score").cast("float")).alias("avg_rating"))
    measure_step("Average rating per author", "PySpark", step_avg_rating_per_author, log_spark)

    def step_reviews_per_publisher():
        global reviews_per_publisher_df
        reviews_per_publisher_df = merged_df.groupby("publisher").agg(count("Id").alias("num_reviews"))
    measure_step("Number of reviews per publisher", "PySpark", step_reviews_per_publisher, log_spark)

    def step_top10_categories():
        global category_reviews_df
        category_reviews_df = merged_df.withColumn("category", explode(col("categories"))) \
            .groupby("category").agg(count("Id").alias("num_reviews")) \
            .orderBy(col("num_reviews").desc()).limit(10)
    measure_step("Top 10 most-reviewed categories", "PySpark", step_top10_categories, log_spark)

    # ---- Text processing ----
    def step_avg_review_length():
        tmp = merged_df.withColumn("review_length", size(split(col("review/text"), " ")))
        tmp.selectExpr("avg(review_length)").collect()
    measure_step("Average review length", "PySpark", step_avg_review_length, log_spark)

    def step_most_common_words():
        global top_words_df
        words_df = merged_df.select(explode(split(lower(col("review/text")), " ")).alias("word"))
        top_words_df = words_df.groupBy("word").agg(count("*").alias("count")).orderBy(col("count").desc()).limit(10)
    measure_step("Most frequent keywords", "PySpark", step_most_common_words, log_spark)

    # ---- Save ----
    def step_save_results():
        author_ratings_df.toPandas().to_csv("avg_rating_per_author_spark.csv", index=False)
        reviews_per_publisher_df.toPandas().to_csv("reviews_per_publisher_spark.csv", index=False)
        category_reviews_df.toPandas().to_csv("top10_categories_spark.csv", index=False)
        top_words_df.toPandas().to_csv("top10_keywords_spark.csv", index=False)

    spark.stop()

    pd.DataFrame(log_spark).to_csv("emissions_spark.csv", index=False)
    print("✅ PySpark pipeline done → emissions_spark.csv")

# Run Task 2
spark_pipeline()
# Out:
# [codecarbon INFO @ 10:46:10] Energy consumed for RAM : 0.000033 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:10] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:10] Energy consumed for All CPU : 0.000071 kWh
# [codecarbon INFO @ 10:46:10] 0.000104 kWh of electricity and 0.000000 L of water were used since the beginning.
# Running PySpark pipeline...
# [codecarbon INFO @ 10:46:10] Energy consumed for RAM : 0.000061 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:10] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:10] Energy consumed for All CPU : 0.000130 kWh
# [codecarbon INFO @ 10:46:10] 0.000191 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:10] Energy consumed for RAM : 0.000022 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:10] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:10] Energy consumed for All CPU : 0.000048 kWh
# [codecarbon INFO @ 10:46:10] 0.000070 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:11] Energy consumed for RAM : 0.000050 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:11] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:11] Energy consumed for All CPU : 0.000107 kWh
# [codecarbon INFO @ 10:46:11] 0.000157 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:11] Energy consumed for RAM : 0.000078 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:11] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:11] Energy consumed for All CPU : 0.000166 kWh
# [codecarbon INFO @ 10:46:11] 0.000244 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:11] Energy consumed for RAM : 0.000039 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:11] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:11] Energy consumed for All CPU : 0.000083 kWh
# [codecarbon INFO @ 10:46:11] 0.000122 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:11] Energy consumed for RAM : 0.000066 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:11] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:11] Energy consumed for All CPU : 0.000142 kWh
# [codecarbon INFO @ 10:46:11] 0.000208 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:11] Energy consumed for RAM : 0.000028 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:11] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:11] Energy consumed for All CPU : 0.000059 kWh
# [codecarbon INFO @ 10:46:11] 0.000087 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:12] Energy consumed for RAM : 0.000056 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:12] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:12] Energy consumed for All CPU : 0.000119 kWh
# [codecarbon INFO @ 10:46:12] 0.000174 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:12] Energy consumed for RAM : 0.000083 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:12] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:12] Energy consumed for All CPU : 0.000178 kWh
# [codecarbon INFO @ 10:46:12] 0.000261 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:12] Energy consumed for RAM : 0.000044 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:12] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:12] Energy consumed for All CPU : 0.000095 kWh
# [codecarbon INFO @ 10:46:12] 0.000139 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:12] Energy consumed for RAM : 0.000072 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:12] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:12] Energy consumed for All CPU : 0.000154 kWh
# [codecarbon INFO @ 10:46:12] 0.000225 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:12] Energy consumed for RAM : 0.000033 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:12] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:12] Energy consumed for All CPU : 0.000071 kWh
# [codecarbon INFO @ 10:46:12] 0.000104 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:13] Energy consumed for RAM : 0.000061 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:13] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:13] Energy consumed for All CPU : 0.000131 kWh
# [codecarbon INFO @ 10:46:13] 0.000192 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:13] Energy consumed for RAM : 0.000089 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:13] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:13] Energy consumed for All CPU : 0.000190 kWh
# [codecarbon INFO @ 10:46:13] 0.000278 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:13] Energy consumed for RAM : 0.000050 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:13] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:13] Energy consumed for All CPU : 0.000107 kWh
# [codecarbon INFO @ 10:46:13] 0.000156 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:13] Energy consumed for RAM : 0.000077 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:13] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:13] Energy consumed for All CPU : 0.000166 kWh
# [codecarbon INFO @ 10:46:13] 0.000243 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:13] Energy consumed for RAM : 0.000039 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:13] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:14] Energy consumed for All CPU : 0.000083 kWh
# [codecarbon INFO @ 10:46:14] 0.000122 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:14] Energy consumed for RAM : 0.000066 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:14] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:14] Energy consumed for All CPU : 0.000143 kWh
# [codecarbon INFO @ 10:46:14] 0.000209 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:14] Energy consumed for RAM : 0.000094 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:14] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:14] Energy consumed for All CPU : 0.000201 kWh
# [codecarbon INFO @ 10:46:14] 0.000296 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:14] Energy consumed for RAM : 0.000055 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:14] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:14] Energy consumed for All CPU : 0.000118 kWh
# [codecarbon INFO @ 10:46:14] 0.000174 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:14] Energy consumed for RAM : 0.000083 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:14] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:14] Energy consumed for All CPU : 0.000177 kWh
# [codecarbon INFO @ 10:46:14] 0.000260 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:14] Energy consumed for RAM : 0.000044 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:14] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:14] Energy consumed for All CPU : 0.000095 kWh
# [codecarbon INFO @ 10:46:14] 0.000139 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:15] Energy consumed for RAM : 0.000072 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:15] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:15] Energy consumed for All CPU : 0.000154 kWh
# [codecarbon INFO @ 10:46:15] 0.000226 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:15] Energy consumed for RAM : 0.000100 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:15] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:15] Energy consumed for All CPU : 0.000213 kWh
# [codecarbon INFO @ 10:46:15] 0.000313 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:15] Energy consumed for RAM : 0.000061 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:15] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:15] Energy consumed for All CPU : 0.000130 kWh
# [codecarbon INFO @ 10:46:15] 0.000191 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:15] Energy consumed for RAM : 0.000088 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:15] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:15] Energy consumed for All CPU : 0.000189 kWh
# [codecarbon INFO @ 10:46:15] 0.000278 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:15] Energy consumed for RAM : 0.000050 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:16] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:16] Energy consumed for All CPU : 0.000107 kWh
# [codecarbon INFO @ 10:46:16] 0.000157 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:16] Energy consumed for RAM : 0.000078 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:16] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:16] Energy consumed for All CPU : 0.000166 kWh
# [codecarbon INFO @ 10:46:16] 0.000244 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:16] Energy consumed for RAM : 0.000105 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:16] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:16] Energy consumed for All CPU : 0.000225 kWh
# [codecarbon INFO @ 10:46:16] 0.000330 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:16] Energy consumed for RAM : 0.000066 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:16] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:16] Energy consumed for All CPU : 0.000142 kWh
# [codecarbon INFO @ 10:46:16] 0.000208 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:16] Energy consumed for RAM : 0.000094 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:16] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:16] Energy consumed for All CPU : 0.000201 kWh
# [codecarbon INFO @ 10:46:16] 0.000295 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:17] Energy consumed for RAM : 0.000055 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:17] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:17] Energy consumed for All CPU : 0.000119 kWh
# [codecarbon INFO @ 10:46:17] 0.000174 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:17] Energy consumed for RAM : 0.000083 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:17] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:17] Energy consumed for All CPU : 0.000178 kWh
# [codecarbon INFO @ 10:46:17] 0.000261 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:17] Energy consumed for RAM : 0.000111 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:17] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:17] Energy consumed for All CPU : 0.000237 kWh
# [codecarbon INFO @ 10:46:17] 0.000348 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:17] Energy consumed for RAM : 0.000072 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:17] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:17] Energy consumed for All CPU : 0.000154 kWh
# [codecarbon INFO @ 10:46:17] 0.000226 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:17] Energy consumed for RAM : 0.000099 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:17] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:17] Energy consumed for All CPU : 0.000213 kWh
# [codecarbon INFO @ 10:46:17] 0.000312 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:18] Energy consumed for RAM : 0.000061 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:18] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:18] Energy consumed for All CPU : 0.000131 kWh
# [codecarbon INFO @ 10:46:18] 0.000191 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:18] Energy consumed for RAM : 0.000089 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:18] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:18] Energy consumed for All CPU : 0.000190 kWh
# [codecarbon INFO @ 10:46:18] 0.000279 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:18] Energy consumed for RAM : 0.000116 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:18] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:18] Energy consumed for All CPU : 0.000249 kWh
# [codecarbon INFO @ 10:46:18] 0.000365 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:18] Energy consumed for RAM : 0.000077 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:18] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:18] Energy consumed for All CPU : 0.000166 kWh
# [codecarbon INFO @ 10:46:18] 0.000243 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:18] Energy consumed for RAM : 0.000105 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:18] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:18] Energy consumed for All CPU : 0.000225 kWh
# [codecarbon INFO @ 10:46:18] 0.000330 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:19] Energy consumed for RAM : 0.000066 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:19] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:19] Energy consumed for All CPU : 0.000143 kWh
# [codecarbon INFO @ 10:46:19] 0.000209 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:19] Energy consumed for RAM : 0.000094 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:19] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:19] Energy consumed for All CPU : 0.000202 kWh
# [codecarbon INFO @ 10:46:19] 0.000296 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:19] Energy consumed for RAM : 0.000122 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:19] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:19] Energy consumed for All CPU : 0.000261 kWh
# [codecarbon INFO @ 10:46:19] 0.000382 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:19] Energy consumed for RAM : 0.000083 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:19] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:19] Energy consumed for All CPU : 0.000178 kWh
# [codecarbon INFO @ 10:46:19] 0.000260 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:19] Energy consumed for RAM : 0.000111 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:19] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:19] Energy consumed for All CPU : 0.000237 kWh
# [codecarbon INFO @ 10:46:19] 0.000347 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:20] Energy consumed for RAM : 0.000072 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:20] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:20] Energy consumed for All CPU : 0.000154 kWh
# [codecarbon INFO @ 10:46:20] 0.000226 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:20] Energy consumed for RAM : 0.000100 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:20] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:20] Energy consumed for All CPU : 0.000214 kWh
# [codecarbon INFO @ 10:46:20] 0.000313 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:20] Energy consumed for RAM : 0.000127 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:20] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:20] Energy consumed for All CPU : 0.000273 kWh
# [codecarbon INFO @ 10:46:20] 0.000400 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:20] Energy consumed for RAM : 0.000088 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:20] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:20] Energy consumed for All CPU : 0.000190 kWh
# [codecarbon INFO @ 10:46:20] 0.000278 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:20] Energy consumed for RAM : 0.000116 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:20] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:20] Energy consumed for All CPU : 0.000249 kWh
# [codecarbon INFO @ 10:46:20] 0.000365 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:21] Energy consumed for RAM : 0.000077 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:21] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:21] Energy consumed for All CPU : 0.000166 kWh
# [codecarbon INFO @ 10:46:21] 0.000243 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:21] Energy consumed for RAM : 0.000105 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:21] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:21] Energy consumed for All CPU : 0.000225 kWh
# [codecarbon INFO @ 10:46:21] 0.000331 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:21] Energy consumed for RAM : 0.000133 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:21] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:21] Energy consumed for All CPU : 0.000285 kWh
# [codecarbon INFO @ 10:46:21] 0.000417 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:21] Energy consumed for RAM : 0.000094 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:21] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:21] Energy consumed for All CPU : 0.000201 kWh
# [codecarbon INFO @ 10:46:21] 0.000295 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:21] Energy consumed for RAM : 0.000122 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:21] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:21] Energy consumed for All CPU : 0.000261 kWh
# [codecarbon INFO @ 10:46:21] 0.000382 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:22] Energy consumed for RAM : 0.000083 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:22] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:22] Energy consumed for All CPU : 0.000178 kWh
# [codecarbon INFO @ 10:46:22] 0.000261 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:22] Energy consumed for RAM : 0.000111 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:22] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:22] Energy consumed for All CPU : 0.000238 kWh
# [codecarbon INFO @ 10:46:22] 0.000349 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:22] Energy consumed for RAM : 0.000138 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:22] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:22] Energy consumed for All CPU : 0.000296 kWh
# [codecarbon INFO @ 10:46:22] 0.000435 kWh of electricity and 0.000000 L of water were used since the beginning.
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[5], line 94
#      91     print("✅ PySpark pipeline done → emissions_spark.csv")
#      93 # Run Task 2
# ---> 94 spark_pipeline()
#
# Cell In[5], line 46, in spark_pipeline()
#      43     merged_df = reviews_df_clean.join(books_df_clean, on="Title", how="inner")
#      45 # Call the data loading and preparation steps first
# ---> 46 step_load_data()
#      47 step_clean_data()
#      48 step_join_data()
#
# Cell In[5], line 17, in spark_pipeline.<locals>.step_load_data()
#      15 def step_load_data():
#      16     global books_df, reviews_df
# ---> 17     books_df = spark.read.option("header", True).csv("books.csv")
#      18     reviews_df = spark.read.option("header", True).csv("reviews.csv")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pyspark\sql\readwriter.py:740, in DataFrameReader.csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     738 if type(path) == list:
#     739     assert self._spark._sc._jvm is not None
# --> 740     return self._df(self._jreader.csv(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#     741 elif isinstance(path, RDD):
#     743     def func(iterator):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\py4j\java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pyspark\errors\exceptions\captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [PATH_NOT_FOUND] Path does not exist: file:/c:/Users/Gaurav Chugh/source/GreenComputing_TP2/books.csv.
# [codecarbon INFO @ 10:46:22] Energy consumed for RAM : 0.000099 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:22] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:22] Energy consumed for All CPU : 0.000213 kWh
# [codecarbon INFO @ 10:46:22] 0.000313 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:22] Energy consumed for RAM : 0.000127 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:22] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:22] Energy consumed for All CPU : 0.000272 kWh
# [codecarbon INFO @ 10:46:22] 0.000400 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:23] Energy consumed for RAM : 0.000088 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:23] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:23] Energy consumed for All CPU : 0.000190 kWh
# [codecarbon INFO @ 10:46:23] 0.000278 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:23] Energy consumed for RAM : 0.000116 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:23] Delta energy consumed for CPU with constant : 0.000011 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:23] Energy consumed for All CPU : 0.000249 kWh
# [codecarbon INFO @ 10:46:23] 0.000365 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:23] Energy consumed for RAM : 0.000144 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:23] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:23] Energy consumed for All CPU : 0.000308 kWh
# [codecarbon INFO @ 10:46:23] 0.000452 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:23] Energy consumed for RAM : 0.000105 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:23] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:23] Energy consumed for All CPU : 0.000225 kWh
# [codecarbon INFO @ 10:46:23] 0.000330 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:23] Energy consumed for RAM : 0.000133 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:23] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:23] Energy consumed for All CPU : 0.000284 kWh
# [codecarbon INFO @ 10:46:23] 0.000417 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:24] Energy consumed for RAM : 0.000094 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:24] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:24] Energy consumed for All CPU : 0.000201 kWh
# [codecarbon INFO @ 10:46:24] 0.000295 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:24] Energy consumed for RAM : 0.000122 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:24] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:24] Energy consumed for All CPU : 0.000261 kWh
# [codecarbon INFO @ 10:46:24] 0.000382 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:24] Energy consumed for RAM : 0.000149 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:24] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:24] Energy consumed for All CPU : 0.000320 kWh
# [codecarbon INFO @ 10:46:24] 0.000469 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:24] Energy consumed for RAM : 0.000110 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:24] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:24] Energy consumed for All CPU : 0.000237 kWh
# [codecarbon INFO @ 10:46:24] 0.000347 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:24] Energy consumed for RAM : 0.000138 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:24] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:24] Energy consumed for All CPU : 0.000296 kWh
# [codecarbon INFO @ 10:46:24] 0.000434 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:25] Energy consumed for RAM : 0.000100 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:25] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:25] Energy consumed for All CPU : 0.000214 kWh
# [codecarbon INFO @ 10:46:25] 0.000313 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:25] Energy consumed for RAM : 0.000127 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:25] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:25] Energy consumed for All CPU : 0.000273 kWh
# [codecarbon INFO @ 10:46:25] 0.000400 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:25] Energy consumed for RAM : 0.000155 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:25] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:25] Energy consumed for All CPU : 0.000332 kWh
# [codecarbon INFO @ 10:46:25] 0.000487 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:25] Energy consumed for RAM : 0.000116 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:25] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:25] Energy consumed for All CPU : 0.000249 kWh
# [codecarbon INFO @ 10:46:25] 0.000365 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:25] Energy consumed for RAM : 0.000144 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:25] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:25] Energy consumed for All CPU : 0.000308 kWh
# [codecarbon INFO @ 10:46:25] 0.000452 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:26] Energy consumed for RAM : 0.000105 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:26] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:26] Energy consumed for All CPU : 0.000225 kWh
# [codecarbon INFO @ 10:46:26] 0.000330 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:26] Energy consumed for RAM : 0.000133 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:26] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:26] Energy consumed for All CPU : 0.000284 kWh
# [codecarbon INFO @ 10:46:26] 0.000417 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:26] Energy consumed for RAM : 0.000160 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:26] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:26] Energy consumed for All CPU : 0.000344 kWh
# [codecarbon INFO @ 10:46:26] 0.000504 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:26] Energy consumed for RAM : 0.000121 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:26] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:26] Energy consumed for All CPU : 0.000261 kWh
# [codecarbon INFO @ 10:46:26] 0.000382 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:26] Energy consumed for RAM : 0.000149 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:26] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:26] Energy consumed for All CPU : 0.000320 kWh
# [codecarbon INFO @ 10:46:26] 0.000469 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:27] Energy consumed for RAM : 0.000110 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:27] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:27] Energy consumed for All CPU : 0.000237 kWh
# [codecarbon INFO @ 10:46:27] 0.000347 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:27] Energy consumed for RAM : 0.000138 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:27] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:27] Energy consumed for All CPU : 0.000296 kWh
# [codecarbon INFO @ 10:46:27] 0.000435 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:27] Energy consumed for RAM : 0.000166 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:27] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:27] Energy consumed for All CPU : 0.000356 kWh
# [codecarbon INFO @ 10:46:27] 0.000521 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:27] Energy consumed for RAM : 0.000127 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:27] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:27] Energy consumed for All CPU : 0.000273 kWh
# [codecarbon INFO @ 10:46:27] 0.000400 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:27] Energy consumed for RAM : 0.000155 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:27] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:27] Energy consumed for All CPU : 0.000332 kWh
# [codecarbon INFO @ 10:46:27] 0.000487 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:28] Energy consumed for RAM : 0.000116 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:28] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:28] Energy consumed for All CPU : 0.000249 kWh
# [codecarbon INFO @ 10:46:28] 0.000365 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:28] Energy consumed for RAM : 0.000144 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:28] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:28] Energy consumed for All CPU : 0.000308 kWh
# [codecarbon INFO @ 10:46:28] 0.000452 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:28] Energy consumed for RAM : 0.000171 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:28] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:28] Energy consumed for All CPU : 0.000367 kWh
# [codecarbon INFO @ 10:46:28] 0.000539 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:28] Energy consumed for RAM : 0.000132 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:28] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:28] Energy consumed for All CPU : 0.000284 kWh
# [codecarbon INFO @ 10:46:28] 0.000417 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:28] Energy consumed for RAM : 0.000160 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:28] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:28] Energy consumed for All CPU : 0.000343 kWh
# [codecarbon INFO @ 10:46:28] 0.000504 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:29] Energy consumed for RAM : 0.000122 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:29] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:29] Energy consumed for All CPU : 0.000261 kWh
# [codecarbon INFO @ 10:46:29] 0.000382 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:29] Energy consumed for RAM : 0.000149 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:29] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:29] Energy consumed for All CPU : 0.000320 kWh
# [codecarbon INFO @ 10:46:29] 0.000469 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:29] Energy consumed for RAM : 0.000177 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:29] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:29] Energy consumed for All CPU : 0.000379 kWh
# [codecarbon INFO @ 10:46:29] 0.000556 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:29] Energy consumed for RAM : 0.000138 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:29] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:29] Energy consumed for All CPU : 0.000296 kWh
# [codecarbon INFO @ 10:46:29] 0.000434 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:29] Energy consumed for RAM : 0.000166 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:29] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:29] Energy consumed for All CPU : 0.000355 kWh
# [codecarbon INFO @ 10:46:29] 0.000521 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:30] Energy consumed for RAM : 0.000127 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:30] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:30] Energy consumed for All CPU : 0.000273 kWh
# [codecarbon INFO @ 10:46:30] 0.000400 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:30] Energy consumed for RAM : 0.000155 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:30] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:30] Energy consumed for All CPU : 0.000332 kWh
# [codecarbon INFO @ 10:46:30] 0.000487 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:30] Energy consumed for RAM : 0.000183 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:30] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:30] Energy consumed for All CPU : 0.000391 kWh
# [codecarbon INFO @ 10:46:30] 0.000574 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:30] Energy consumed for RAM : 0.000143 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:30] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:30] Energy consumed for All CPU : 0.000308 kWh
# [codecarbon INFO @ 10:46:30] 0.000451 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:30] Energy consumed for RAM : 0.000171 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:30] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:30] Energy consumed for All CPU : 0.000367 kWh
# [codecarbon INFO @ 10:46:30] 0.000538 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:31] Energy consumed for RAM : 0.000133 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:31] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:31] Energy consumed for All CPU : 0.000284 kWh
# [codecarbon INFO @ 10:46:31] 0.000417 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:31] Energy consumed for RAM : 0.000161 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:31] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:31] Energy consumed for All CPU : 0.000344 kWh
# [codecarbon INFO @ 10:46:31] 0.000505 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:31] Energy consumed for RAM : 0.000188 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:31] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:31] Energy consumed for All CPU : 0.000403 kWh
# [codecarbon INFO @ 10:46:31] 0.000591 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:31] Energy consumed for RAM : 0.000149 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:31] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:31] Energy consumed for All CPU : 0.000320 kWh
# [codecarbon INFO @ 10:46:31] 0.000469 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:31] Energy consumed for RAM : 0.000177 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:31] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:31] Energy consumed for All CPU : 0.000379 kWh
# [codecarbon INFO @ 10:46:31] 0.000556 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:32] Energy consumed for RAM : 0.000138 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:32] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:32] Energy consumed for All CPU : 0.000296 kWh
# [codecarbon INFO @ 10:46:32] 0.000434 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:32] Energy consumed for RAM : 0.000166 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:32] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:32] Energy consumed for All CPU : 0.000356 kWh
# [codecarbon INFO @ 10:46:32] 0.000522 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:32] Energy consumed for RAM : 0.000194 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:32] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:32] Energy consumed for All CPU : 0.000415 kWh
# [codecarbon INFO @ 10:46:32] 0.000609 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:32] Energy consumed for RAM : 0.000154 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:32] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:32] Energy consumed for All CPU : 0.000332 kWh
# [codecarbon INFO @ 10:46:32] 0.000486 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:32] Energy consumed for RAM : 0.000182 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:32] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:32] Energy consumed for All CPU : 0.000391 kWh
# [codecarbon INFO @ 10:46:32] 0.000573 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:33] Energy consumed for RAM : 0.000144 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:33] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:33] Energy consumed for All CPU : 0.000308 kWh
# [codecarbon INFO @ 10:46:33] 0.000451 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:33] Energy consumed for RAM : 0.000171 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:33] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:33] Energy consumed for All CPU : 0.000367 kWh
# [codecarbon INFO @ 10:46:33] 0.000539 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:33] Energy consumed for RAM : 0.000199 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:33] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:33] Energy consumed for All CPU : 0.000427 kWh
# [codecarbon INFO @ 10:46:33] 0.000626 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:33] Energy consumed for RAM : 0.000160 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:33] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:33] Energy consumed for All CPU : 0.000344 kWh
# [codecarbon INFO @ 10:46:33] 0.000504 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:33] Energy consumed for RAM : 0.000188 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:33] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:33] Energy consumed for All CPU : 0.000403 kWh
# [codecarbon INFO @ 10:46:33] 0.000591 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:34] Energy consumed for RAM : 0.000149 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:34] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:34] Energy consumed for All CPU : 0.000320 kWh
# [codecarbon INFO @ 10:46:34] 0.000469 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:34] Energy consumed for RAM : 0.000177 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:34] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:34] Energy consumed for All CPU : 0.000379 kWh
# [codecarbon INFO @ 10:46:34] 0.000556 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:34] Energy consumed for RAM : 0.000205 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:46:34] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:46:34] Energy consumed for All CPU : 0.000439 kWh
# [codecarbon INFO @ 10:46:34] 0.000643 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:46:34] Energy consumed for RAM : 0.000166 kWh. RAM Power : 20.0 W
# ...
# [codecarbon INFO @ 10:48:22] Energy consumed for All CPU : 0.001702 kWh
# [codecarbon INFO @ 10:48:22] 0.002496 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:22] Energy consumed for RAM : 0.000756 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:22] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:22] Energy consumed for All CPU : 0.001621 kWh
# [codecarbon INFO @ 10:48:22] 0.002377 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:22] Energy consumed for RAM : 0.000784 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:22] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:22] Energy consumed for All CPU : 0.001681 kWh
# [codecarbon INFO @ 10:48:22] 0.002465 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:22] Energy consumed for RAM : 0.000746 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:22] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:22] Energy consumed for All CPU : 0.001599 kWh
# [codecarbon INFO @ 10:48:22] 0.002344 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:23] Energy consumed for RAM : 0.000773 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:23] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:23] Energy consumed for All CPU : 0.001657 kWh
# [codecarbon INFO @ 10:48:23] 0.002430 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:23] Energy consumed for RAM : 0.000800 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:23] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:23] Energy consumed for All CPU : 0.001714 kWh
# [codecarbon INFO @ 10:48:23] 0.002514 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:23] Energy consumed for RAM : 0.000761 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:23] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:23] Energy consumed for All CPU : 0.001633 kWh
# [codecarbon INFO @ 10:48:23] 0.002395 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:23] Energy consumed for RAM : 0.000790 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:23] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:23] Energy consumed for All CPU : 0.001692 kWh
# [codecarbon INFO @ 10:48:23] 0.002482 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:23] Energy consumed for RAM : 0.000751 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:23] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:23] Energy consumed for All CPU : 0.001610 kWh
# [codecarbon INFO @ 10:48:23] 0.002362 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:24] Energy consumed for RAM : 0.000779 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:24] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:24] Energy consumed for All CPU : 0.001669 kWh
# [codecarbon INFO @ 10:48:24] 0.002447 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:24] Energy consumed for RAM : 0.000805 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:24] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:24] Energy consumed for All CPU : 0.001726 kWh
# [codecarbon INFO @ 10:48:24] 0.002531 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:24] Energy consumed for RAM : 0.000767 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:24] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:24] Energy consumed for All CPU : 0.001645 kWh
# [codecarbon INFO @ 10:48:24] 0.002412 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:24] Energy consumed for RAM : 0.000795 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:24] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:24] Energy consumed for All CPU : 0.001704 kWh
# [codecarbon INFO @ 10:48:24] 0.002500 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:24] Energy consumed for RAM : 0.000757 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:24] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:24] Energy consumed for All CPU : 0.001622 kWh
# [codecarbon INFO @ 10:48:24] 0.002379 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:25] Energy consumed for RAM : 0.000784 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:25] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:25] Energy consumed for All CPU : 0.001681 kWh
# [codecarbon INFO @ 10:48:25] 0.002465 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:25] Energy consumed for RAM : 0.000811 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:25] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:25] Energy consumed for All CPU : 0.001738 kWh
# [codecarbon INFO @ 10:48:25] 0.002549 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:25] Energy consumed for RAM : 0.000772 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:25] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:25] Energy consumed for All CPU : 0.001657 kWh
# [codecarbon INFO @ 10:48:25] 0.002429 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:25] Energy consumed for RAM : 0.000801 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:25] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:25] Energy consumed for All CPU : 0.001716 kWh
# [codecarbon INFO @ 10:48:25] 0.002517 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:25] Energy consumed for RAM : 0.000762 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:25] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:25] Energy consumed for All CPU : 0.001634 kWh
# [codecarbon INFO @ 10:48:25] 0.002397 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:26] Energy consumed for RAM : 0.000790 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:26] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:26] Energy consumed for All CPU : 0.001693 kWh
# [codecarbon INFO @ 10:48:26] 0.002482 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:26] Energy consumed for RAM : 0.000816 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:26] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:26] Energy consumed for All CPU : 0.001750 kWh
# [codecarbon INFO @ 10:48:26] 0.002566 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:26] Energy consumed for RAM : 0.000778 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:26] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:26] Energy consumed for All CPU : 0.001669 kWh
# [codecarbon INFO @ 10:48:26] 0.002446 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:26] Energy consumed for RAM : 0.000806 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:26] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:26] Energy consumed for All CPU : 0.001728 kWh
# [codecarbon INFO @ 10:48:26] 0.002534 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:27] Energy consumed for RAM : 0.000768 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:27] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:27] Energy consumed for All CPU : 0.001646 kWh
# [codecarbon INFO @ 10:48:27] 0.002414 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:27] Energy consumed for RAM : 0.000795 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:27] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:27] Energy consumed for All CPU : 0.001705 kWh
# [codecarbon INFO @ 10:48:27] 0.002500 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:27] Energy consumed for RAM : 0.000822 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:27] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:27] Energy consumed for All CPU : 0.001762 kWh
# [codecarbon INFO @ 10:48:27] 0.002584 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:27] Energy consumed for RAM : 0.000783 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:27] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:27] Energy consumed for All CPU : 0.001681 kWh
# [codecarbon INFO @ 10:48:27] 0.002464 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:27] Energy consumed for RAM : 0.000812 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:27] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:27] Energy consumed for All CPU : 0.001740 kWh
# [codecarbon INFO @ 10:48:27] 0.002552 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:28] Energy consumed for RAM : 0.000773 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:28] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:28] Energy consumed for All CPU : 0.001658 kWh
# [codecarbon INFO @ 10:48:28] 0.002431 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:28] Energy consumed for RAM : 0.000801 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:28] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:28] Energy consumed for All CPU : 0.001716 kWh
# [codecarbon INFO @ 10:48:28] 0.002517 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:28] Energy consumed for RAM : 0.000827 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:28] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:28] Energy consumed for All CPU : 0.001774 kWh
# [codecarbon INFO @ 10:48:28] 0.002601 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:28] Energy consumed for RAM : 0.000789 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:28] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:28] Energy consumed for All CPU : 0.001692 kWh
# [codecarbon INFO @ 10:48:28] 0.002481 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:28] Energy consumed for RAM : 0.000818 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:28] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:28] Energy consumed for All CPU : 0.001752 kWh
# [codecarbon INFO @ 10:48:28] 0.002569 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:29] Energy consumed for RAM : 0.000779 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:29] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:29] Energy consumed for All CPU : 0.001670 kWh
# [codecarbon INFO @ 10:48:29] 0.002449 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:29] Energy consumed for RAM : 0.000806 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:29] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:29] Energy consumed for All CPU : 0.001728 kWh
# [codecarbon INFO @ 10:48:29] 0.002535 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:29] Energy consumed for RAM : 0.000833 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:29] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:29] Energy consumed for All CPU : 0.001785 kWh
# [codecarbon INFO @ 10:48:29] 0.002618 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:29] Energy consumed for RAM : 0.000795 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:29] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:29] Energy consumed for All CPU : 0.001704 kWh
# [codecarbon INFO @ 10:48:29] 0.002499 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:29] Energy consumed for RAM : 0.000823 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:29] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:29] Energy consumed for All CPU : 0.001764 kWh
# [codecarbon INFO @ 10:48:29] 0.002587 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:30] Energy consumed for RAM : 0.000784 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:30] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:30] Energy consumed for All CPU : 0.001681 kWh
# [codecarbon INFO @ 10:48:30] 0.002466 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:30] Energy consumed for RAM : 0.000812 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:30] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:30] Energy consumed for All CPU : 0.001740 kWh
# [codecarbon INFO @ 10:48:30] 0.002552 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:30] Energy consumed for RAM : 0.000838 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:30] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:30] Energy consumed for All CPU : 0.001797 kWh
# [codecarbon INFO @ 10:48:30] 0.002636 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:30] Energy consumed for RAM : 0.000800 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:30] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:30] Energy consumed for All CPU : 0.001716 kWh
# [codecarbon INFO @ 10:48:30] 0.002516 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 10:48:30] Energy consumed for RAM : 0.000829 kWh. RAM Power : 20.0 W
# [codecarbon INFO @ 10:48:30] Delta energy consumed for CPU with constant : 0.000012 kWh, power : 42.5 W
# [codecarbon INFO @ 10:48:30] Energy consumed for All CPU : 0.001776 kWh
# [codecarbon INFO @ 10:48:30] 0.002604 kWh of electricity and 0.000000 L of water were used since the beginning.
